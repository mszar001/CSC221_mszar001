# %% [markdown]
# <a href="https://colab.research.google.com/github/mszar001/CSC221_mszar001/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#alien.py

alien_0 = {}
alien_0['color'] = 'green'
alien_0['points'] = 5

print(alien_0['color'])
print(alien_0['points'])

new_points = alien_0['points']
print(f"You just earned {new_points} points!")

print(alien_0)
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)

print(f"The alien is {alien_0['color']}.")
alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")

print("\n")

#movement in alien.py
alien_0['speed'] = 'medium'
print(f"Original position: {alien_0['x_position']}.")

if(alien_0['speed'] == 'slow'):
  x_increment = 1
elif(alien_0['speed'] == 'medium'):
  x_increment = 2
elif(alien_0['speed'] == 'fast'):
  x_increment = 3

alien_0['x_position'] = alien_0['x_position'] + x_increment
print(f"New position: {alien_0['x_position']}.")

print(alien_0)
del alien_0['points']
print(alien_0)

print("\n")
#favorite_languages.py
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'rust',
    'phil': 'python'
}
language = favorite_languages['sarah'].title()
print(f"Sarah's favorite language is {language}.")


print("\n")
#alien_no_points.py

point_value = alien_0.get('points', 'No point value assigned.')
print(point_value)
# Out:
# green
# 5
# You just earned 5 points!
# {'color': 'green', 'points': 5}
# {'color': 'green', 'points': 5, 'x_position': 0, 'y_position': 25}
# The alien is green.
# The alien is now yellow.
#
#
# Original position: 0.
# New position: 2.
# {'color': 'yellow', 'points': 5, 'x_position': 2, 'y_position': 25, 'speed': 'medium'}
# {'color': 'yellow', 'x_position': 2, 'y_position': 25, 'speed': 'medium'}
#
#
# Sarah's favorite language is C.
#
#
# No point value assigned.

# %%
#6-1 'Person'
ashe = {'first_name': 'ashe', 'last_name': 'greene', 'age': '19', 'city': 'albany'}
print(ashe['first_name'].title())
print(ashe['last_name'].title())
print(ashe['age'])
print(ashe['city'].title())

print("\n")
#6-2, 'Favorite Numbers'
num = {'kenna': 42, 'erica': 12, 'morgan': 24, 'alyx': 47, 'ashe': 8}
print(f"Kenna's favorite number is {num['kenna']}")
print(f"Erica's favorite number is {num['erica']}")
print(f"Morgan's favorite number is {num['morgan']}")
print(f"Alyx's favorite number is {num['alyx']}")
print(f"Ashe's favorite number is {num['ashe']}")

print("\n")
#6-3 'Glossary'
glossary = {
    'print': 'prints what is within the parenthesis',
    'while': 'Loops through until the statement within the loop is "False"',
    'if': 'A type of control that checks a statement, and if true, does something',
    'else': 'A control that is the "catch-all" for things that dont pass the if statement',
    'elif': 'A combo of "else" and "if" to an "if not A" it then moves onto "B", checking conditions like an if statement.'
}
print(f"print: {glossary['print']}\n")
print(f"while: {glossary['while']}\n")
print(f"if: {glossary['if']}\n")
print(f"else: {glossary['else']}\n")
print(f"elif: {glossary['elif']}\n")
# Out:
# Ashe
# Greene
# 19
# Albany
#
#
# Kenna's favorite number is 42
# Erica's favorite number is 12
# Morgan's favorite number is 24
# Alyx's favorite number is 47
# Ashe's favorite number is 8
#
#
# print: prints what is within the parenthesis
#
# while: Loops through until the statement within the loop is "False"
#
# if: A type of control that checks a statement, and if true, does something
#
# else: A control that is the "catch-all" for things that dont pass the if statement
#
# elif: A combo of "else" and "if" to an "if not A" it then moves onto "B", checking conditions like an if statement.

# %%
#user.py
user_0 = {
    'username': 'efermi',
    'first': 'enrico',
    'last': 'fermi',
}
for key, value in user_0.items():
  print(f"\nKey: {key}")
  print(f"Value: {value}")

#This would've been very convienent for earlier haha!
print("\n")
#favorite_languages.py (again)
for name, language in favorite_languages.items():
  print(f"{name.title()}'s favorite language is {language.title()}.")

print("\n")
friends = ['phil', 'sarah']
for name in favorite_languages.keys():
  print(f"Hi {name.title()}!")
  if name in friends:
    language = favorite_languages[name].title()
    print(f"\t{name.title()}, I see you love {language}!")

print("\n")
for name in sorted(favorite_languages.keys()):
  print(f"{name.title()}, thank you for taking the poll.")
if('erin not in favorite_languages.keys()'):
  print("Erin, please take our poll.")

print("\n")
print("The following languages have been mentioned:")
for language in set(favorite_languages.values()):
  print(language.title())
# Out:
# Key: username
# Value: efermi
#
# Key: first
# Value: enrico
#
# Key: last
# Value: fermi
#
#
# Jen's favorite language is Python.
# Sarah's favorite language is C.
# Edward's favorite language is Rust.
# Phil's favorite language is Python.
#
#
# Hi Jen!
# Hi Sarah!
# 	Sarah, I see you love C!
# Hi Edward!
# Hi Phil!
# 	Phil, I see you love Python!
#
#
# Edward, thank you for taking the poll.
# Jen, thank you for taking the poll.
# Phil, thank you for taking the poll.
# Sarah, thank you for taking the poll.
# Erin, please take our poll.
#
#
# The following languages have been mentioned:
# Rust
# Python
# C

# %%
#6-4 'Glossary 2'
for term, definition in glossary.items():
  print(f"{term}: {definition}\n")
#There we go, neat and tidy...
# Out:
# print: prints what is within the parenthesis
#
# while: Loops through until the statement within the loop is "False"
#
# if: A type of control that checks a statement, and if true, does something
#
# else: A control that is the "catch-all" for things that dont pass the if statement
#
# elif: A combo of "else" and "if" to an "if not A" it then moves onto "B", checking conditions like an if statement.

# %%
#aliens.py
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}

aliens = [alien_0, alien_1, alien_2]

for alien in aliens:
  print(alien)

print("\n")
aliens = []
for alien_number in range(30):
  new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
  aliens.append(new_alien)
for alien in aliens[:3]:
  if alien['color'] == 'green':
    alien['color'] = 'yellow'
    alien['speed'] = 'medium'
    alien['points'] = 10
  elif alien['color'] == 'yellow':
    alien['color'] = 'red'
    alien['speed'] = 'fast'
    alien['points'] = 15

for alien in aliens[:5]:
  print(alien)
print("...")
print(f"Total number of aliens: {len(aliens)}")

print("\n")
#pizza.py
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese'],
}
print(f"You ordered a {pizza['crust']}-crust pizza"
" with the following toppings:")
for topping in pizza['toppings']:
  print(f"\t{topping}")

print("\n")
#favorite_languages.py (again)
favorite_languages = {
    'jen': ['python', 'rust'],
    'sarah': ['c'],
    'edward': ['rust', 'go'],
    'phil': ['python', 'haskell'],
}
for name, languages in favorite_languages.items():
  print(f"\n{name.title()}'s favorite languages are: ")
  for language in languages:
    print(f"\t{language.title()}")

print("\n")
#many_users.py
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton',
    },
    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris',
    }
}

for username, user_info in users.items():
  print(f"\nUsername: {username}")
  full_name = f"{user_info['first']} {user_info['last']}"
  location = user_info['location']

  print(f"\tFull name: {full_name.title()}")
  print(f"\tLocation: {location.title()}")
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}
#
#
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# Total number of aliens: 30
#
#
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese
#
#
#
# Jen's favorite languages are:
# 	Python
# 	Rust
#
# Sarah's favorite languages are:
# 	C
#
# Edward's favorite languages are:
# 	Rust
# 	Go
#
# Phil's favorite languages are:
# 	Python
# 	Haskell
#
#
#
# Username: aeinstein
# 	Full name: Albert Einstein
# 	Location: Princeton
#
# Username: mcurie
# 	Full name: Marie Curie
# 	Location: Paris

# %%
#6-11 'Cities'
cities = {
    'denver': {
        'country': 'United States',
        'population': 700000,
        'fact': 'Denver is called the "Mile High City" as the city is a mile above sea level',
    },
    'new york city': {
        'country': 'United States',
        'population': 7888000,
        'fact': 'One of the worlds largest libraries is in NYC',
    },
    'albany': {
        'country': 'United States',
        'population': 638000,
        'fact': 'Albany is the oldest continuous settlement from the original 13 colonies'
    },
}

for city, city_info in cities.items():
  print(f"City: {city.title()}")
  for names, details in city_info.items():
    print(f"\t{names.title()}: {details}")
  print("\n")

print("\n")
#6-12 'Extensions'
#I'm going to extend on the pizza one. I like pizza, what can I say? Haha!

available = {
    'crust': ['thick', 'thin'],
    'toppings': ['mushrooms', 'extra cheese', 'sausage', 'pepperoni'],
}
order = []
crust = input(f"What kind of crust would you like? We have the options of: {available['crust']} ")
if crust in available['crust']:
  order.append(crust)
  while(True):
    top = input(f"What kind of toppings would you like? We have the options of: {available['toppings']}. "
    "Type 'exit' to exit.")
    if(top == 'exit'):
      break
    elif(top in available['toppings']):
      order.append(top)
    else:
      print("N/A... try again?")
print(f"you ordered a {order[0]}-crust pizza with the following toppings:")
for topping in order[1:]:
  print(topping)

#hm.. I suppose I ended up using lists more so than dictionaries, but.. it does work I guess.
# Out:
# City: Denver
# 	Country: United States
# 	Population: 700000
# 	Fact: Denver is called the "Mile High City" as the city is a mile above sea level
#
#
# City: New York City
# 	Country: United States
# 	Population: 7888000
# 	Fact: One of the worlds largest libraries is in NYC
#
#
# City: Albany
# 	Country: United States
# 	Population: 638000
# 	Fact: Albany is the oldest continuous settlement from the original 13 colonies
#
#
#
#
# What kind of crust would you like? We have the options of: ['thick', 'thin'] thick
# What kind of toppings would you like? We have the options of: ['mushrooms', 'extra cheese', 'sausage', 'pepperoni']. Type 'exit' to exit.pepperoni
# What kind of toppings would you like? We have the options of: ['mushrooms', 'extra cheese', 'sausage', 'pepperoni']. Type 'exit' to exit.sausage
# What kind of toppings would you like? We have the options of: ['mushrooms', 'extra cheese', 'sausage', 'pepperoni']. Type 'exit' to exit.extra cheese
# ...
